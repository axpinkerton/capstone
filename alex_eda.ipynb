# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import warnings
warnings.simplefilter('ignore')

# %%
markets = pd.read_excel('./SFR Markets.xlsx')
top20_lst = list(set(markets['Top 20 SFR Markets']))
top100_lst = list(set(markets['Top 100 SFR Markets']))
top20_lst
# Out:
# [nan,
#  'Riverside, CA',
#  'Tucson, AZ',
#  'Las Vegas, NV',
#  'Atlanta, GA',
#  'Memphis, TN',
#  'Boise City, ID',
#  'Jacksonville, FL',
#  'Raleigh, NC',
#  'Indianapolis, IN',
#  'Nashville, TN',
#  'Austin, TX',
#  'Miami-Fort Lauderdale, FL',
#  'Denver, CO',
#  'Orlando, FL',
#  'Tampa, FL',
#  'Houston, TX',
#  'Phoenix, AZ',
#  'Sacramento, CA',
#  'Fort Collins, CO',
#  'Dallas-Fort Worth, TX']

# %%
top100 = pd.read_excel('./Top_100.xlsx')
top100
# Out:
#                            3D City DB  \
# 0                                AARP
# 1             Administration on Aging
# 2                         Atlanta Fed
# 3   Bank of International Settlements
# 4                         Best Places
# ..                                ...
# 94                               USGS
# 95                  USGS National Map
# 96          World Resources Institute
# 97                             Zillow
# 98                          FBI (UCR)
#
#        https://www.3dcitydb.org/3dcitydb/d3ddatabase/
# 0                   https://livabilityindex.aarp.org/
# 1   https://eldercare.acl.gov/Public/Site_Utilitie...
# 2                         https://www.frbatlanta.org/
# 3    https://www.bis.org/statistics/pp_commercial.htm
# 4   https://www.bestplaces.net/data/setup.aspx?dat...
# ..                                                ...
# 94     https://catalog.data.gov/organization/usgs-gov
# 95  https://www.sciencebase.gov/catalog/item/4f552...
# ...

# %%
MF_rr = pd.read_csv('./Zip_Zri_MultiFamilyResidenceRental.csv')
MF_rr
# Out:
#       RegionID  RegionName            City State  \
# 0        61639       10025        New York    NY
# 1        84654       60657         Chicago    IL
# 2        61637       10023        New York    NY
# 3        91982       77494            Katy    TX
# 4        84616       60614         Chicago    IL
# ...        ...         ...             ...   ...
# 1856     90755       75202          Dallas    TX
# 1857     94610       84627         Ephraim    UT
# 1858     84452       60301        Oak Park    IL
# 1859     94629       84647  Mount Pleasant    UT
# 1860     91695       77046         Houston    TX
#
#                                  Metro       CountyName  SizeRank  2010-09  \
# 0          New York-Newark-Jersey City  New York County         1   2930.0
# 1             Chicago-Naperville-Elgin      Cook County         2   1447.0
# 2          New York-Newark-Jersey City  New York County         3   2797.0
# ...

# %%
SF_rr = pd.read_csv('./Zip_Zri_SingleFamilyResidenceRental.csv')
SF_rr
# Out:
#        RegionID  RegionName          City State  \
# 0         84654       60657       Chicago    IL
# 1         91982       77494          Katy    TX
# 2         84616       60614       Chicago    IL
# 3         91940       77449          Katy    TX
# 4         93144       79936       El Paso    TX
# ...         ...         ...           ...   ...
# 15831     99032       97028  Rhododendron    OR
# 15832     62697       12720        Bethel    NY
# 15833     99074       97102     Arch Cape    OR
# 15834     58333        1338      Buckland    MA
# 15835     66881       21405     Annapolis    MD
#
#                                   Metro           CountyName  SizeRank  \
# 0              Chicago-Naperville-Elgin          Cook County         1
# 1      Houston-The Woodlands-Sugar Land        Harris County         2
# 2              Chicago-Naperville-Elgin          Cook County         3
# 3      Houston-The Woodlands-Sugar Land        Harris County         4
# ...

# %%
AH_mf = pd.read_csv('./Zip_Zri_AllHomesPlusMultifamily.csv')
AH_mf
# Out:
#        RegionID  RegionName       City State  \
# 0         61639       10025   New York    NY
# 1         84654       60657    Chicago    IL
# 2         61637       10023   New York    NY
# 3         91982       77494       Katy    TX
# 4         84616       60614    Chicago    IL
# ...         ...         ...        ...   ...
# 13176     68966       26291   Snowshoe    WV
# 13177     62697       12720     Bethel    NY
# 13178     68924       26209   Snowshoe    WV
# 13179     75924       41101    Ashland    KY
# 13180     95851       89155  Las Vegas    NV
#
#                                   Metro         CountyName  SizeRank  2010-09  \
# 0           New York-Newark-Jersey City    New York County         1   3031.0
# 1              Chicago-Naperville-Elgin        Cook County         2   1790.0
# 2           New York-Newark-Jersey City    New York County         3   3269.0
# 3      Houston-The Woodlands-Sugar Land      Harris County         4   1547.0
# ...

# %%
zori = pd.read_csv('./Metro_ZORI_AllHomesPlusMultifamily_SSA.csv')
zori
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1340.0   1347.0
# 1      394913                        New York, NY         1   2402.0   2414.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1755.0   1772.0
# 3      394463                         Chicago, IL         3   1454.0   1459.0
# 4      394514               Dallas-Fort Worth, TX         4   1139.0   1146.0
# ..        ...                                 ...       ...      ...      ...
# 101    394995                  Port St. Lucie, FL       119   1163.0   1172.0
# 102    394602                    Fort Collins, CO       159   1133.0   1148.0
# 103    394405                         Boulder, CO       162   1437.0   1449.0
# 104    394645                         Greeley, CO       177   1182.0   1194.0
# 105    394623                     Gainesville, GA       229    926.0    929.0
#
# ...

# %%
zori_zip = pd.read_csv('./Zip_ZORI_AllHomesPlusMultifamily_SSA.csv')
df1 = zori_zip.set_index('RegionName')

# %%
df2 = AH_mf.set_index('RegionName')
df2
# Out:
#             RegionID       City State                             Metro  \
# RegionName
# 10025          61639   New York    NY       New York-Newark-Jersey City
# 60657          84654    Chicago    IL          Chicago-Naperville-Elgin
# 10023          61637   New York    NY       New York-Newark-Jersey City
# 77494          91982       Katy    TX  Houston-The Woodlands-Sugar Land
# 60614          84616    Chicago    IL          Chicago-Naperville-Elgin
# ...              ...        ...   ...                               ...
# 26291          68966   Snowshoe    WV                               NaN
# 12720          62697     Bethel    NY                               NaN
# 26209          68924   Snowshoe    WV                               NaN
# 41101          75924    Ashland    KY                Huntington-Ashland
# 89155          95851  Las Vegas    NV      Las Vegas-Henderson-Paradise
#
#                    CountyName  SizeRank  2010-09  2010-10  2010-11  2010-12  \
# RegionName
# ...

# %%
df3 = df1.drop(['RegionID','SizeRank','MsaName'],axis=1)
df4 = df2.drop(df2.iloc[:,0:46],axis=1)

# %%
df5 = df3.merge(df4,left_index=True, right_index=True)
df5 = df5.sort_index(axis=1)

# %%
df5[['2014-01_x', '2014-01_y']]
len(df5.columns)
range(163)
df6 = pd.DataFrame()
for x in range(163):
    if x%2==0:
        print(np.mean(np.correlate(df5.iloc[x].dropna(),df5.iloc[x+1].dropna())))
# Out:
# 798193396.3870968
# 752040896.6969697
# 457331259.5
# 546266765.0285715
# 228980288.0
# 442477292.0
# 1639783958.2068965
# 403252645.0
# 964692322.0
# 434057285.0
# 526333649.42105263
# 560980566.8529412
# 362944337.8333333
# 755804020.1891892
# 286039624.0
# 251115974.75
# 236275328.0
# 847123233.0
# 509650103.0
# 509606784.5
# 331309180.0
# 308767505.4444444
# 616815028.9047619
# 351712416.5
# 405862570.0
# 323585660.5
# 396658253.0
# 1064729696.0
# 515398488.0
# 599725801.0
# 267467197.75
# 491347066.29787236
# 291540596.5
# 509762137.5
# 217369399.5
# 422029303.0
# 791801704.6666666
# 260898657.0
# 844116261.75
# 332728165.5
# 328444479.0
# 800144974.0
# 744440965.5
# 297845469.5
# 626556917.0
# 150886768.33333334
# 511882069.9
# 406444117.0
# 426978072.75
# 254641298.0
# 619039902.0
# 311748985.72727275
# 952259073.0
# 191168291.0
# 566753158.0
# 504074324.5
# 370302557.0
# 359235637.0
# 215567299.7
# 409020663.0
# 217286260.5
# 522565315.5
# 218221717.8125
# 335910035.0
# ...

# %%
zori
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1340.0   1347.0
# 1      394913                        New York, NY         1   2402.0   2414.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1755.0   1772.0
# 3      394463                         Chicago, IL         3   1454.0   1459.0
# 4      394514               Dallas-Fort Worth, TX         4   1139.0   1146.0
# ..        ...                                 ...       ...      ...      ...
# 101    394995                  Port St. Lucie, FL       119   1163.0   1172.0
# 102    394602                    Fort Collins, CO       159   1133.0   1148.0
# 103    394405                         Boulder, CO       162   1437.0   1449.0
# 104    394645                         Greeley, CO       177   1182.0   1194.0
# 105    394623                     Gainesville, GA       229    926.0    929.0
#
# ...

# %%
covid = pd.read_csv('./us_counties_covid19_daily.csv')
covid
# covid['year']=x['date']
# covid['month']=x

covid['year']=covid['date'].str[0:4]
covid['month']=covid['date'].str[5:7]
covid['mo_yr']=covid['month']+"/"+covid['year']

import calendar
calendar.monthrange(2020,1)


covid['month'] = pd.to_numeric(covid['month'])
covid['year'] = pd.to_numeric(covid['year'])
# calendar.monthrange(
calendar.monthrange(2019, 2)[1] # num_day
covid['days_in_mo'] = covid['mo_yr'].apply(lambda t: pd.Period(t, freq='S').days_in_month)
covid
# Out:
#               date      county       state     fips  cases  deaths  year  \
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0  2020
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0  2020
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0  2020
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0  2020
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0  2020
# ...            ...         ...         ...      ...    ...     ...   ...
# 800432  2020-12-05  Sweetwater     Wyoming  56037.0   2098    10.0  2020
# 800433  2020-12-05       Teton     Wyoming  56039.0   1739     2.0  2020
# 800434  2020-12-05       Uinta     Wyoming  56041.0   1187     5.0  2020
# 800435  2020-12-05    Washakie     Wyoming  56043.0    519     8.0  2020
# 800436  2020-12-05      Weston     Wyoming  56045.0    419     2.0  2020
#
#         month    mo_yr  day_in_mo
# 0           1  01/2020         31
# ...

# %%
len(covid.date)
# Out:
# 800437

# %%
covid['new_col'] = covid['year'].astype(str)+'-'+covid['date'].str[5:7]+'-'+covid['day_in_mo'].astype(str)
covid['last_flag']= covid['date']==covid['new_col']
covid_df = covid[covid['last_flag']]

# %%
X = zori.iloc[:,3:87].fillna(0)
y = zori.iloc[:,88].fillna(0)
zori.isnull().sum()/len(zori)
# Out:
# RegionID      0.000000
# RegionName    0.000000
# SizeRank      0.000000
# 2014-01       0.066038
# 2014-02       0.009434
#                 ...
# 2021-01       0.000000
# 2021-02       0.000000
# 2021-03       0.000000
# 2021-04       0.000000
# 2021-05       0.009434
# Length: 92, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X,y,test_size=.25)

ols = LinearRegression()
ols.fit(X_tr,y_tr)
ols.score(X_tr,y_tr)
ols.score(X_te,y_te)

# np.mean(np.array(y_te - ols.predict(X_te)))
# Out:
# 0.8887393566082412

# %%
zip_county = pd.read_csv('https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv')
zip_county
# Out:
#        state_fips    state state_abbr zipcode      county        city
# 0               1  Alabama         AL   35004   St. Clair       Acmar
# 1               1  Alabama         AL   35005   Jefferson  Adamsville
# 2               1  Alabama         AL   35006   Jefferson       Adger
# 3               1  Alabama         AL   35007      Shelby    Keystone
# 4               1  Alabama         AL   35010  Tallapoosa    New site
# ...           ...      ...        ...     ...         ...         ...
# 33098          56  Wyoming         WY   83126     Lincoln       Smoot
# 33099          56  Wyoming         WY   83127     Lincoln      Thayne
# 33100          56  Wyoming         WY   83128     Lincoln      Alpine
# 33101          56  Wyoming         WY   831HH     Lincoln  Zcta 831hh
# 33102          56  Wyoming         WY   831XX     Lincoln  Zcta 831xx
#
# [33103 rows x 6 columns]

# %%
covid_df.sort_values(by=['state','county','date'],inplace=True)
# Out:
# <ipython-input-256-bf631b43a657>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_df.sort_values(by=['state','county','date'],inplace=True)

# %%
covid_df['new_cases']=covid_df['cases']-covid_df['cases'].shift(1)
covid_df['new_deaths']=covid_df['deaths']-covid_df['deaths'].shift(1)
covid_df.to_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/covid_csv.csv')
# Out:
# <ipython-input-260-70448e6f292b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_df['new_cases']=covid_df['cases']-covid_df['cases'].shift(1)
# <ipython-input-260-70448e6f292b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_df['new_deaths']=covid_df['deaths']-covid_df['deaths'].shift(1)

# %%
covid_df.to_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/covid_csv.csv')

# %%
covid_df = pd.read_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/capstone_csv_covid.csv')

# %%
covid_df['county_state'] = covid_df['county'] + covid_df['state']
len(covid_df['county_state'].unique())
# Out:
# 3260

# %%
covid_df
# Out:
#        Unnamed: 0        date   county    state     fips  cases  deaths  year  \
# 0           21727  2020-03-31  Autauga  Alabama   1001.0      7     0.0  2020
# 1          101015  2020-04-30  Autauga  Alabama   1001.0     42     4.0  2020
# 2          193780  2020-05-31  Autauga  Alabama   1001.0    221     4.0  2020
# 3          287109  2020-06-30  Autauga  Alabama   1001.0    537    12.0  2020
# 4          385994  2020-07-31  Autauga  Alabama   1001.0   1015    21.0  2020
# ...           ...         ...      ...      ...      ...    ...     ...   ...
# 27433      389210  2020-07-31   Weston  Wyoming  56045.0      5     0.0  2020
# 27434      489195  2020-08-31   Weston  Wyoming  56045.0     19     0.0  2020
# 27435      586301  2020-09-30   Weston  Wyoming  56045.0     39     0.0  2020
# 27436      686853  2020-10-31   Weston  Wyoming  56045.0    163     0.0  2020
# 27437      784209  2020-11-30   Weston  Wyoming  56045.0    397     1.0  2020
#
# ...

# %%
cities = pd.read_csv('./counties_cities.csv')
cities['county'] = cities['RegionName'].str[:-7]

# %%
cities.to_csv('counties_cities.csv')

# %%
cities_counties = pd.read_csv('counties_cities.csv')
cities_counties
# Out:
#       Unnamed: 0  RegionID  SizeRank          RegionName RegionType StateName  \
# 0              0      3101         0  Los Angeles County     County        CA
# 1              1       139         1         Cook County     County        IL
# 2              2      1090         2       Harris County     County        TX
# 3              3      2402         3     Maricopa County     County        AZ
# 4              4      2841         4    San Diego County     County        CA
# ...          ...       ...       ...                 ...        ...       ...
# 2863        2863       425      3101        Camas County     County        ID
# 2864        2864      1648      3102      Daggett County     County        UT
# 2865        2865      2345      3112     Hinsdale County     County        CO
# 2866        2866      1933      3122      Mineral County     County        CO
# 2867        2867      2518      3124     San Juan County     County        CO
#
# ...

# %%
covid_df
# Out:
#        Unnamed: 0        date   county    state     fips  cases  deaths  year  \
# 0           21727  2020-03-31  Autauga  Alabama   1001.0      7     0.0  2020
# 1          101015  2020-04-30  Autauga  Alabama   1001.0     42     4.0  2020
# 2          193780  2020-05-31  Autauga  Alabama   1001.0    221     4.0  2020
# 3          287109  2020-06-30  Autauga  Alabama   1001.0    537    12.0  2020
# 4          385994  2020-07-31  Autauga  Alabama   1001.0   1015    21.0  2020
# ...           ...         ...      ...      ...      ...    ...     ...   ...
# 27433      389210  2020-07-31   Weston  Wyoming  56045.0      5     0.0  2020
# 27434      489195  2020-08-31   Weston  Wyoming  56045.0     19     0.0  2020
# 27435      586301  2020-09-30   Weston  Wyoming  56045.0     39     0.0  2020
# 27436      686853  2020-10-31   Weston  Wyoming  56045.0    163     0.0  2020
# 27437      784209  2020-11-30   Weston  Wyoming  56045.0    397     1.0  2020
#
# ...

# %%
import statsmodels.tsa.statespace.sarimax
import statsmodels.api as sm
top20_forecast_input_train = pd.read_csv('./top20_forecast_input_train.csv')
top20_forecast_input_train.drop('Unnamed: 0',axis=1,inplace=True)
top20_forecast_input_train
# Out:
#          MsaName month_yr    mean_rent
# 0    Atlanta, GA  2014-01  1090.912088
# 1    Atlanta, GA  2014-02  1108.100000
# 2    Atlanta, GA  2014-03  1119.797980
# 3    Atlanta, GA  2014-04  1119.735849
# 4    Atlanta, GA  2014-05  1128.728972
# ..           ...      ...          ...
# 955   Tucson, AZ  2017-08  1042.312500
# 956   Tucson, AZ  2017-09  1045.812500
# 957   Tucson, AZ  2017-10  1049.500000
# 958   Tucson, AZ  2017-11  1053.812500
# 959   Tucson, AZ  2017-12  1058.187500
#
# [960 rows x 3 columns]

# %%
mod = sm.tsa.statespace.SARIMAX(top20_forecast_input_train['mean_rent'], order=(0,1,0), seasonal_order=(0,1,0,12))
res = mod.fit(disp=1)
print(res.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                          mean_rent   No. Observations:                  960
# Model:             SARIMAX(0, 1, 0)x(0, 1, 0, 12)   Log Likelihood               -5473.078
# Date:                            Thu, 15 Jul 2021   AIC                          10948.157
# Time:                                    18:04:33   BIC                          10953.010
# Sample:                                         0   HQIC                         10950.006
#                                             - 960
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      6130.9037     60.932    100.619      0.000    6011.479    6250.328
# ...
# Ljung-Box (L1) (Q):                   2.12   Jarque-Bera (JB):             65630.70
# ...

# %%
lst = []
for idx, msa in enumerate(top20_forecast_input_train.MsaName.unique()):
      lst.append((idx,pd.DataFrame(top20_forecast_input_train[top20_forecast_input_train['MsaName']==msa])))

# %%
msas = list(top20_forecast_input_train.MsaName.unique())
top20_forecast_input_train[top20_forecast_input_train['MsaName']==l]['mean_rent']
len(top20_forecast_input_train[top20_forecast_input_train['MsaName']==l]['mean_rent'])
# Out:
# 48

# %%
for l in msas:
    mod = sm.tsa.statespace.SARIMAX(top20_forecast_input_train[top20_forecast_input_train['MsaName']==l]['mean_rent'], order=(0,1,0), seasonal_order=(0,1,0,12))
    res = mod.fit(disp=1)
    print(res.predict(params=res.params,start=48,end=50))
    print(res.summary())
# Out:
# 48    1366.414262
# 49    1368.021738
# 50    1373.187107
# Name: predicted_mean, dtype: float64
#                                      SARIMAX Results
# ...
# Dep. Variable:                          mean_rent   No. Observations:                   48
# Model:             SARIMAX(0, 1, 0)x(0, 1, 0, 12)   Log Likelihood                -112.765
# Date:                            Thu, 15 Jul 2021   AIC                            227.530
# Time:                                    19:16:36   BIC                            229.086
# Sample:                                         0   HQIC                           228.067
#                                              - 48
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        36.8133      7.485      4.918      0.000      22.142      51.484
# ...

# %%
def show_graph(df1,df2,title):
    data = pd.concat([df1, df2])
    data.reset_index(inplace=True, drop=True)
    for col in data.columns:
        if col.lower().startswith('pred'):
            data[col].plot(label=col,linestyle="dotted")
        else:
            data[col].plot(label=col)
    plt.title(title)
    plt.legend()
    plt.show()

# %%
from statsmodels.tsa.statespace.varmax import VARMAX
from random import random

def VARMA_model(train,test):
    # fit model
    model = VARMAX(train, order=(1, 2))
    model_fit = model.fit(disp=False)
    # make prediction
    yhat = model_fit.forecast(steps=len(test))
    res=pd.DataFrame({"Pred1":yhat['Act1'], "Pred2":yhat['Act2'], 
                      "Act1":test["Act1"].values, "Act2":test["Act2"].values})
    return res

df_train = pd.DataFrame({'Act1':[x + random()*10 for x in range(0, 100)],
                         'Act2':50+np.sin(np.linspace(0, 2*np.pi, 100))*50})
df_test = pd.DataFrame({'Act1':[x + random()*10 for x in range(101, 201)],
                         'Act2':50+np.sin(np.linspace(0, 2*np.pi, 100))*50})
df_ret = VARMA_model(df_train, df_test)
show_graph(df_train, df_ret, "Vector Autoregression Moving-Average (VARMA)")

# %%
def VARMAX_model(train,test):
    # fit model
    model = VARMAX(train.drop('Exog', axis=1), exog=train['Exog'], order=(1, 1))
    model_fit = model.fit(disp=False)
    # make prediction
    yhat = model_fit.forecast(steps=len(test),exog=test['Exog'])
    res=pd.DataFrame({"Pred1":yhat['Act1'], "Pred2":yhat['Act2'], 
            "Act1":test["Act1"].values, "Act2":test["Act2"].values, "Exog":test["Exog"].values})
    return res

df_train = pd.DataFrame({'Act1':[x + random()*10 for x in range(0, 100)],
                         'Act2':[x*3 + random()*10 for x in range(0, 100)],
                         'Exog':50+np.sin(np.linspace(0, 2*np.pi, 100))*50})
df_test = pd.DataFrame({'Act1':[x + random()*10 for x in range(101, 201)],
                         'Act2':[x*3 + random()*10 for x in range(101, 201)],
                         'Exog':50+np.sin(np.linspace(0, 2*np.pi, 100))*50})
df_ret = VARMAX_model(df_train, df_test)
show_graph(df_train, df_ret,"Vector Autoregression Moving-Average with Exogenous Regressors (VARMAX)")

# %%
melted_df[~melted_df['month'].isin(['2021-01','2021-02'])]
# Out:
#        RegionName    month    rent  year
# 2529        01603  2014-03  1024.0  2014
# 5255        01603  2014-04  1011.0  2014
# 7981        01603  2014-05   998.0  2014
# 10707       01603  2014-06     NaN  2014
# 13433       01603  2014-07   972.0  2014
# ...           ...      ...     ...   ...
# 219990      99216  2020-11  1063.0  2020
# 222716      99216  2020-12  1076.0  2020
# 230894      99216  2021-03  1118.0  2021
# 233620      99216  2021-04  1132.0  2021
# 236346      99216  2021-05  1146.0  2021
#
# [231710 rows x 4 columns]

# %%
melted_df['year']=melted_df['month'].str[0:4]
training = melted_df[melted_df['year']<2021]
testing = melted_df[melted_df['year']>=2021]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-634-82f85919aa42> in <module>
#       1 melted_df['year']=melted_df['month'].str[0:4]
# ----> 2 training = melted_df[melted_df['year']<2021]
#       3 testing = melted_df[melted_df['year']>=2021]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ...

# %%
zori
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1340.0   1347.0
# 1      394913                        New York, NY         1   2402.0   2414.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1755.0   1772.0
# 3      394463                         Chicago, IL         3   1454.0   1459.0
# 4      394514               Dallas-Fort Worth, TX         4   1139.0   1146.0
# ..        ...                                 ...       ...      ...      ...
# 101    394995                  Port St. Lucie, FL       119   1163.0   1172.0
# 102    394602                    Fort Collins, CO       159   1133.0   1148.0
# 103    394405                         Boulder, CO       162   1437.0   1449.0
# 104    394645                         Greeley, CO       177   1182.0   1194.0
# 105    394623                     Gainesville, GA       229    926.0    929.0
#
# ...

# %%
zori_zip = pd.read_csv('./Zip_ZORI_AllHomesPlusMultifamily_SSA.csv')
zori_zip
# Out:
#       RegionID  RegionName  SizeRank                             MsaName  \
# 0        61639       10025         1                        New York, NY
# 1        84654       60657         2                         Chicago, IL
# 2        61637       10023         3                        New York, NY
# 3        91982       77494         4                         Houston, TX
# 4        84616       60614         5                         Chicago, IL
# ...        ...         ...       ...                                 ...
# 2721     58622        2108      8986                          Boston, MA
# 2722     96048       90067      9219  Los Angeles-Long Beach-Anaheim, CA
# 2723     66128       20004      9592                      Washington, DC
# 2724    399647       80951      9634                Colorado Springs, CO
# 2725     84604       60602     10262                         Chicago, IL
#
#       2014-01  2014-02  2014-03  2014-04  2014-05  2014-06  2014-07  2014-08  \
# ...

# %%
us_zips = pd.read_csv('uszips.csv')
us_zips = us_zips[['zip', 'city', 'state_id', 'state_name','county_fips', 'county_name','county_names_all', 'county_fips_all']]

# %%
def fix_zip(series):
      return series.astype(str).str.replace('[^\w\s]', '').str.zfill(5)
us_zips['fixed_zip'] = fix_zip(us_zips['zip'])

# %%
us_zips
# Out:
#          zip         city state_id   state_name  county_fips  \
# 0        601     Adjuntas       PR  Puerto Rico        72001
# 1        602       Aguada       PR  Puerto Rico        72003
# 2        603    Aguadilla       PR  Puerto Rico        72005
# 3        606      Maricao       PR  Puerto Rico        72093
# 4        610       Anasco       PR  Puerto Rico        72011
# ...      ...          ...      ...          ...          ...
# 33116  99923        Hyder       AK       Alaska         2198
# 33117  99925      Klawock       AK       Alaska         2198
# 33118  99926   Metlakatla       AK       Alaska         2198
# 33119  99927  Point Baker       AK       Alaska         2198
# 33120  99929     Wrangell       AK       Alaska         2275
#
#                  county_name             county_names_all    county_fips_all  \
# 0                   Adjuntas              Adjuntas|Utuado        72001|72141
# ...

# %%
covid_df = pd.read_csv('covid_df.csv')
covid_df.drop('Unnamed: 0',axis=1,inplace=True)
covid_df
# Out:
#              date   county    state     fips  cases  new_cases  deaths  \
# 0      2020-03-31  Autauga  Alabama   1001.0      7          7       0
# 1      2020-04-30  Autauga  Alabama   1001.0     42         35       4
# 2      2020-05-31  Autauga  Alabama   1001.0    221        186       4
# 3      2020-06-30  Autauga  Alabama   1001.0    537        351      12
# 4      2020-07-31  Autauga  Alabama   1001.0   1015        664      21
# ...           ...      ...      ...      ...    ...        ...     ...
# 48952  2021-02-28   Weston  Wyoming  56045.0    622        230       5
# 48953  2021-03-31   Weston  Wyoming  56045.0    633        403       5
# 48954  2021-04-30   Weston  Wyoming  56045.0    650        247       5
# 48955  2021-05-31   Weston  Wyoming  56045.0    654        407       5
# 48956  2021-06-30   Weston  Wyoming  56045.0    657        250       6
#
#        new_deaths  year  month    mo_yr  days_in_mo     new_col  last_flag  \
# ...

# %%
zori_zip['RegionName']= fix_zip(zori_zip['RegionName'])

# %%
pvt_tbl = zori_zip.pivot_table(columns='RegionName').drop(['RegionID','SizeRank'],axis=0)
sorted(list(zip(pvt_tbl.columns,pvt_tbl.isnull().sum()/len(pvt_tbl))),key=lambda t:t[1],reverse=True)
# Out:
# [('32169', 0.3707865168539326),
#  ('95130', 0.34831460674157305),
#  ('55391', 0.3258426966292135),
#  ('95111', 0.3258426966292135),
#  ('08033', 0.29213483146067415),
#  ('11550', 0.29213483146067415),
#  ('94015', 0.29213483146067415),
#  ('94803', 0.2808988764044944),
#  ('90067', 0.2696629213483146),
#  ('37909', 0.25842696629213485),
#  ('95242', 0.25842696629213485),
#  ('94619', 0.24719101123595505),
#  ('14621', 0.23595505617977527),
#  ('22032', 0.23595505617977527),
#  ('29651', 0.23595505617977527),
#  ('76119', 0.23595505617977527),
#  ('06615', 0.2247191011235955),
#  ('07652', 0.2247191011235955),
#  ('53204', 0.2247191011235955),
#  ('60602', 0.2247191011235955),
#  ('63101', 0.2247191011235955),
#  ('78724', 0.2247191011235955),
#  ('94116', 0.2247191011235955),
#  ('19096', 0.21348314606741572),
#  ('20015', 0.21348314606741572),
#  ('23237', 0.21348314606741572),
#  ('55126', 0.21348314606741572),
#  ('55443', 0.21348314606741572),
# ...

# %%
party = pd.read_csv('./president_county_candidate.csv')
party['county_st'] = party['county'] +', ' + party['state']
party['just_co']=party['county'].str[:-6]
party.to_csv('election.csv')

# %%
party
# Out:
#           state             county      candidate party  total_votes    won  \
# 0      Delaware        Kent County      Joe Biden   DEM        44552   True
# 1      Delaware        Kent County   Donald Trump   REP        41009  False
# 2      Delaware        Kent County   Jo Jorgensen   LIB         1044  False
# 3      Delaware        Kent County  Howie Hawkins   GRN          420  False
# 4      Delaware  New Castle County      Joe Biden   DEM       195034   True
# ...         ...                ...            ...   ...          ...    ...
# 32172   Arizona    Maricopa County      Write-ins   WRI         1331  False
# 32173   Arizona      Mohave County   Donald Trump   REP        78535   True
# 32174   Arizona      Mohave County      Joe Biden   DEM        24831  False
# 32175   Arizona      Mohave County   Jo Jorgensen   LIB         1302  False
# 32176   Arizona      Mohave County      Write-ins   WRI           37  False
#
#                          county_st      just_co
# ...

# %%
melted_df

covid_df

cities_counties

top20_lst
top100_lst

pvt_tbl
# Out:
#               date     county      state     fips   cases  new_cases  deaths  \
# 1960    2020-03-31    Chilton    Alabama   1021.0      11         11       0
# 1974    2020-04-30    Chilton    Alabama   1021.0      53         42       1
# 1988    2020-05-31    Chilton    Alabama   1021.0     101         59       1
# 2002    2020-06-30    Chilton    Alabama   1021.0     214        155       3
# 2016    2020-07-31    Chilton    Alabama   1021.0     699        544       6
# ...            ...        ...        ...      ...     ...        ...     ...
# 703635  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
# 703639  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
# 703642  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
# 703643  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
# 703645  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
#
# ...

# %%
nl = pd.read_csv('census_nl.csv')
nl.head()

# %%
census = nl[['GEO_ID','DP05_0001E']]
census.drop(0,inplace=True,axis=0)

# %%
census['zip'] = census['GEO_ID'].str[-5:]

# %%
census.columns=['geo_id','ttl_pop','zip']
zip_co = pd.merge(census,county_to_zip[['ZIP','co_st']],left_on='zip',right_on='ZIP')
zip_co.drop('ZIP',axis=1,inplace=True)
zip_co['ttl_pop']=zip_co['ttl_pop'].astype(int)
ttl_county_pop = zip_co.groupby('co_st')[['ttl_pop']].agg(sum)
ttl_county_pop.reset_index(inplace=True)
ttl_county_pop.columns=['county_st',"county_pop"]
county_zip_df = pd.merge(zip_co,ttl_county_pop,left_on='co_st',right_on='county_st')
county_zip_df['percent_to_ttl']=county_zip_df['ttl_pop']/county_zip_df['county_pop']

pd.merge(county_zip_df,covid_df,left_on='county_st',right_on='co_st')

county_zip_df
# Out:
#                geo_id  ttl_pop    zip            co_st        county_st  \
# 0      8600000US35004    12045  35004    St. Clair, AL    St. Clair, AL
# 1      8600000US35052      283  35052    St. Clair, AL    St. Clair, AL
# 2      8600000US35054     4318  35054    St. Clair, AL    St. Clair, AL
# 3      8600000US35094    15059  35094    St. Clair, AL    St. Clair, AL
# 4      8600000US35112      281  35112    St. Clair, AL    St. Clair, AL
# ...               ...      ...    ...              ...              ...
# 46410  8600000US00965     6709  00965  Guaynabo Mu, PR  Guaynabo Mu, PR
# 46411  8600000US00966    15254  00966  Guaynabo Mu, PR  Guaynabo Mu, PR
# 46412  8600000US00968     3448  00968  Guaynabo Mu, PR  Guaynabo Mu, PR
# 46413  8600000US00969    41941  00969  Guaynabo Mu, PR  Guaynabo Mu, PR
# 46414  8600000US00971    25925  00971  Guaynabo Mu, PR  Guaynabo Mu, PR
#
#        county_pop  percent_to_ttl
# 0          174069        0.069197
# ...

# %%
county_zip_covid = pd.merge(covid_df,county_zip_df,left_on='co_st',right_on='co_st')
county_zip_covid.to_csv('county_zip_covid.csv')

# %%
county_zip_covid['yr_mo']=county_zip_covid['date'].str[0:7]

# %%
zori_zips = list(pvt_tbl.columns)

# %%
county_zip_covid[county_zip_covid['zip'].isin(zori_zips)].to_csv('zori_county_zip_covid')

# %%
filtered_covid = county_zip_covid[county_zip_covid['zip'].isin(zori_zips)]
filtered_covid
# Out:
#               date     county      state     fips   cases  new_cases  deaths  \
# 1960    2020-03-31    Chilton    Alabama   1021.0      11         11       0
# 1974    2020-04-30    Chilton    Alabama   1021.0      53         42       1
# 1988    2020-05-31    Chilton    Alabama   1021.0     101         59       1
# 2002    2020-06-30    Chilton    Alabama   1021.0     214        155       3
# 2016    2020-07-31    Chilton    Alabama   1021.0     699        544       6
# ...            ...        ...        ...      ...     ...        ...     ...
# 703635  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
# 703639  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
# 703642  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
# 703643  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
# 703645  2021-06-30  Milwaukee  Wisconsin  55079.0  117852      52902    1428
#
# ...

# %%
filtered_covid['yr_mo']=filtered_covid['date'].str[0:7]
filtered_covid['zip_cases'] = (filtered_covid['cases']*filtered_covid['percent_to_ttl']).astype(int)
filtered_covid['zip_new_cases']=(filtered_covid['new_cases']*filtered_covid['percent_to_ttl']).astype(int)
filtered_covid['zip_deaths'] = (filtered_covid['deaths']*filtered_covid['percent_to_ttl']).astype(int)
filtered_covid['zip_new_deaths']=(filtered_covid['new_deaths']*filtered_covid['percent_to_ttl']).astype(int)

filtered_covid['zip_cases_to_ttl']=filtered_covid['zip_cases']/filtered_covid['ttl_pop']
filtered_covid['zip_new_cases_to_ttl']=filtered_covid['zip_new_cases']/filtered_covid['ttl_pop']
filtered_covid['zip_deaths_to_ttl']=filtered_covid['zip_deaths']/filtered_covid['ttl_pop']
filtered_covid['zip_new_deaths_to_ttl']=filtered_covid['zip_new_deaths']/filtered_covid['ttl_pop']
cleaned_covid = filtered_covid[['yr_mo','zip','zip_cases_to_ttl','zip_new_cases_to_ttl','zip_deaths_to_ttl','zip_new_deaths_to_ttl']]
cleaned_covid
# Out:
#           yr_mo    zip  zip_cases_to_ttl  zip_new_cases_to_ttl  \
# 1960    2020-03  35040          0.000116              0.000116
# 1974    2020-04  35040          0.000635              0.000520
# 1988    2020-05  35040          0.001271              0.000751
# 2002    2020-06  35040          0.002773              0.001964
# 2016    2020-07  35040          0.009012              0.007048
# ...         ...    ...               ...                   ...
# 703635  2021-06  53204          0.122292              0.054889
# 703639  2021-06  53208          0.122310              0.054872
# 703642  2021-06  53211          0.122289              0.054883
# 703643  2021-06  53212          0.122307              0.054901
# 703645  2021-06  53214          0.122303              0.054891
#
#         zip_deaths_to_ttl  zip_new_deaths_to_ttl
# 1960             0.000000               0.000000
# 1974             0.000000               0.000000
# 1988             0.000000               0.000000
# ...

# %%
Xa = cleaned_covid[['yr_mo','zip','zip_cases_to_ttl']].pivot_table(columns='zip',index='yr_mo')
Xb = cleaned_covid[['yr_mo','zip','zip_new_cases_to_ttl']].pivot_table(columns='zip',index='yr_mo')
Xc = cleaned_covid[['yr_mo','zip','zip_deaths_to_ttl']].pivot_table(columns='zip',index='yr_mo')
Xd = cleaned_covid[['yr_mo','zip','zip_new_deaths_to_ttl']].pivot_table(columns='zip',index='yr_mo')

Xa.columns = Xa.columns.droplevel(0)
Xa.reset_index(inplace=True)
Xb.columns=Xb.columns.droplevel(0)
Xb.reset_index(inplace=True)
Xc.columns=Xc.columns.droplevel(0)
Xc.reset_index(inplace=True)
Xd.columns=Xd.columns.droplevel(0)
Xd.reset_index(inplace=True)

# %%
pvt_tbl.index
# train_rent = pvt_tbl[pvt_tbl.index].isin(['2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06',
#        '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12',
#        '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',
#        '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#        '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
#        '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
#        '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#        '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#        '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
#        '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
#        '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12'])

trian_rent = pvt_tbl[pvt_tbl.index.isin(['2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06',
       '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12',
       '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',
       '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
       '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
       '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
       '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
       '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
       '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
       '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
       '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
       '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
       '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
       '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12'])]
test_rent = pvt_tbl[~pvt_tbl.index.isin(['2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06',
       '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12',
       '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',
       '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
       '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
       '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
       '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
       '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
       '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
       '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
       '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
       '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
       '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
       '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12'])]

# %%
def VARMAX_model(train,test):
    # fit model
    model = VARMAX(train.drop('Exog', axis=1), exog=train['Exog'], order=(1, 1))
    model_fit = model.fit(disp=False)
    # make prediction
    yhat = model_fit.forecast(steps=len(test),exog=test['Exog'])
    res=pd.DataFrame({"Pred1":yhat['Act1'], "Pred2":yhat['Act2'], 
            "Act1":test["Act1"].values, "Act2":test["Act2"].values, "Exog":test["Exog"].values})
    return res

df_train = pd.DataFrame({'Act1':[x + random()*10 for x in range(0, 100)],
                         'Act2':[x*3 + random()*10 for x in range(0, 100)],
                         'Exog':50+np.sin(np.linspace(0, 2*np.pi, 100))*50})
df_test = pd.DataFrame({'Act1':[x + random()*10 for x in range(101, 201)],
                         'Act2':[x*3 + random()*10 for x in range(101, 201)],
                         'Exog':50+np.sin(np.linspace(0, 2*np.pi, 100))*50})
df_ret = VARMAX_model(df_train, df_test)
show_graph(df_train, df_ret,"Vector Autoregression Moving-Average with Exogenous Regressors (VARMAX)")
