# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
markets = pd.read_excel('/Users/APinkerton/NYC_DS_A/projects/capstone/SFR Markets.xlsx')
top20_lst = list(set(markets['Top 20 SFR Markets']))
top100_lst = list(set(markets['Top 100 SFR Markets']))
markets
# Out:
#     Top 100 SFR Markets     Top 20 SFR Markets
# 0             Akron, OH            Atlanta, GA
# 1            Albany, NY             Austin, TX
# 2       Albuquerque, NM         Boise City, ID
# 3         Allentown, PA  Dallas-Fort Worth, TX
# 4           Atlanta, GA             Denver, CO
# ..                  ...                    ...
# 101      Washington, DC                    NaN
# 102         Wichita, KS                    NaN
# 103   Winston-Salem, NC                    NaN
# 104       Worcester, MA                    NaN
# 105      Youngstown, OH                    NaN
#
# [106 rows x 2 columns]

# %%
top100 = pd.read_excel('/Users/APinkerton/NYC_DS_A/projects/capstone/Top_100.xlsx')
top100
# Out:
#                            3D City DB  \
# 0                                AARP
# 1             Administration on Aging
# 2                         Atlanta Fed
# 3   Bank of International Settlements
# 4                         Best Places
# ..                                ...
# 94                               USGS
# 95                  USGS National Map
# 96          World Resources Institute
# 97                             Zillow
# 98                          FBI (UCR)
#
#        https://www.3dcitydb.org/3dcitydb/d3ddatabase/
# 0                   https://livabilityindex.aarp.org/
# 1   https://eldercare.acl.gov/Public/Site_Utilitie...
# 2                         https://www.frbatlanta.org/
# 3    https://www.bis.org/statistics/pp_commercial.htm
# 4   https://www.bestplaces.net/data/setup.aspx?dat...
# ..                                                ...
# 94     https://catalog.data.gov/organization/usgs-gov
# 95  https://www.sciencebase.gov/catalog/item/4f552...
# ...

# %%
MF_rr = pd.read_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/Zip_Zri_MultiFamilyResidenceRental.csv')
MF_rr
# Out:
#       RegionID  RegionName            City State  \
# 0        61639       10025        New York    NY
# 1        84654       60657         Chicago    IL
# 2        61637       10023        New York    NY
# 3        91982       77494            Katy    TX
# 4        84616       60614         Chicago    IL
# ...        ...         ...             ...   ...
# 1856     90755       75202          Dallas    TX
# 1857     94610       84627         Ephraim    UT
# 1858     84452       60301        Oak Park    IL
# 1859     94629       84647  Mount Pleasant    UT
# 1860     91695       77046         Houston    TX
#
#                                  Metro       CountyName  SizeRank  2010-09  \
# 0          New York-Newark-Jersey City  New York County         1   2930.0
# 1             Chicago-Naperville-Elgin      Cook County         2   1447.0
# 2          New York-Newark-Jersey City  New York County         3   2797.0
# ...

# %%
SF_rr = pd.read_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/Zip_Zri_SingleFamilyResidenceRental.csv')
SF_rr
# Out:
#        RegionID  RegionName          City State  \
# 0         84654       60657       Chicago    IL
# 1         91982       77494          Katy    TX
# 2         84616       60614       Chicago    IL
# 3         91940       77449          Katy    TX
# 4         93144       79936       El Paso    TX
# ...         ...         ...           ...   ...
# 15831     99032       97028  Rhododendron    OR
# 15832     62697       12720        Bethel    NY
# 15833     99074       97102     Arch Cape    OR
# 15834     58333        1338      Buckland    MA
# 15835     66881       21405     Annapolis    MD
#
#                                   Metro           CountyName  SizeRank  \
# 0              Chicago-Naperville-Elgin          Cook County         1
# 1      Houston-The Woodlands-Sugar Land        Harris County         2
# 2              Chicago-Naperville-Elgin          Cook County         3
# 3      Houston-The Woodlands-Sugar Land        Harris County         4
# ...

# %%
AH_mf = pd.read_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/Zip_Zri_AllHomesPlusMultifamily.csv')
AH_mf
# Out:
#        RegionID  RegionName       City State  \
# 0         61639       10025   New York    NY
# 1         84654       60657    Chicago    IL
# 2         61637       10023   New York    NY
# 3         91982       77494       Katy    TX
# 4         84616       60614    Chicago    IL
# ...         ...         ...        ...   ...
# 13176     68966       26291   Snowshoe    WV
# 13177     62697       12720     Bethel    NY
# 13178     68924       26209   Snowshoe    WV
# 13179     75924       41101    Ashland    KY
# 13180     95851       89155  Las Vegas    NV
#
#                                   Metro         CountyName  SizeRank  2010-09  \
# 0           New York-Newark-Jersey City    New York County         1   3031.0
# 1              Chicago-Naperville-Elgin        Cook County         2   1790.0
# 2           New York-Newark-Jersey City    New York County         3   3269.0
# 3      Houston-The Woodlands-Sugar Land      Harris County         4   1547.0
# ...

# %%
zori = pd.read_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/Metro_ZORI_AllHomesPlusMultifamily_SSA.csv')
zori
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1340.0   1347.0
# 1      394913                        New York, NY         1   2402.0   2414.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1755.0   1772.0
# 3      394463                         Chicago, IL         3   1454.0   1459.0
# 4      394514               Dallas-Fort Worth, TX         4   1139.0   1146.0
# ..        ...                                 ...       ...      ...      ...
# 101    394995                  Port St. Lucie, FL       119   1163.0   1172.0
# 102    394602                    Fort Collins, CO       159   1133.0   1148.0
# 103    394405                         Boulder, CO       162   1437.0   1449.0
# 104    394645                         Greeley, CO       177   1182.0   1194.0
# 105    394623                     Gainesville, GA       229    926.0    929.0
#
# ...

# %%
zori_zip = pd.read_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/Zip_ZORI_AllHomesPlusMultifamily_SSA.csv')
df1 = zori_zip.set_index('RegionName')

# %%
df2 = AH_mf.set_index('RegionName')
df2
# Out:
#             RegionID       City State                             Metro  \
# RegionName
# 10025          61639   New York    NY       New York-Newark-Jersey City
# 60657          84654    Chicago    IL          Chicago-Naperville-Elgin
# 10023          61637   New York    NY       New York-Newark-Jersey City
# 77494          91982       Katy    TX  Houston-The Woodlands-Sugar Land
# 60614          84616    Chicago    IL          Chicago-Naperville-Elgin
# ...              ...        ...   ...                               ...
# 26291          68966   Snowshoe    WV                               NaN
# 12720          62697     Bethel    NY                               NaN
# 26209          68924   Snowshoe    WV                               NaN
# 41101          75924    Ashland    KY                Huntington-Ashland
# 89155          95851  Las Vegas    NV      Las Vegas-Henderson-Paradise
#
#                    CountyName  SizeRank  2010-09  2010-10  2010-11  2010-12  \
# RegionName
# ...

# %%
df3 = df1.drop(['RegionID','SizeRank','MsaName'],axis=1)
df4 = df2.drop(df2.iloc[:,0:46],axis=1)

# %%
df5 = df3.merge(df4,left_index=True, right_index=True)
df5 = df5.sort_index(axis=1)

# %%
df5[['2014-01_x', '2014-01_y']]
len(df5.columns)
range(163)
df6 = pd.DataFrame()
for x in range(163):
    if x%2==0:
        print(np.mean(np.correlate(df5.iloc[x].dropna(),df5.iloc[x+1].dropna())))
# Out:
# 798193396.3870968
# 752040896.6969697
# 457331259.5
# 546266765.0285715
# 228980288.0
# 442477292.0
# 1639783958.2068965
# 403252645.0
# 964692322.0
# 434057285.0
# 526333649.42105263
# 560980566.8529412
# 362944337.8333333
# 755804020.1891892
# 286039624.0
# 251115974.75
# 236275328.0
# 847123233.0
# 509650103.0
# 509606784.5
# 331309180.0
# 308767505.4444444
# 616815028.9047619
# 351712416.5
# 405862570.0
# 323585660.5
# 396658253.0
# 1064729696.0
# 515398488.0
# 599725801.0
# 267467197.75
# 491347066.29787236
# 291540596.5
# 509762137.5
# 217369399.5
# 422029303.0
# 791801704.6666666
# 260898657.0
# 844116261.75
# 332728165.5
# 328444479.0
# 800144974.0
# 744440965.5
# 297845469.5
# 626556917.0
# 150886768.33333334
# 511882069.9
# 406444117.0
# 426978072.75
# 254641298.0
# 619039902.0
# 311748985.72727275
# 952259073.0
# 191168291.0
# 566753158.0
# 504074324.5
# 370302557.0
# 359235637.0
# 215567299.7
# 409020663.0
# 217286260.5
# 522565315.5
# 218221717.8125
# 335910035.0
# ...

# %%
zori
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1340.0   1347.0
# 1      394913                        New York, NY         1   2402.0   2414.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1755.0   1772.0
# 3      394463                         Chicago, IL         3   1454.0   1459.0
# 4      394514               Dallas-Fort Worth, TX         4   1139.0   1146.0
# ..        ...                                 ...       ...      ...      ...
# 101    394995                  Port St. Lucie, FL       119   1163.0   1172.0
# 102    394602                    Fort Collins, CO       159   1133.0   1148.0
# 103    394405                         Boulder, CO       162   1437.0   1449.0
# 104    394645                         Greeley, CO       177   1182.0   1194.0
# 105    394623                     Gainesville, GA       229    926.0    929.0
#
# ...

# %%
covid = pd.read_csv('/Users/APinkerton/NYC_DS_A/projects/capstone/us_counties_covid19_daily.csv')

# covid['year']=x['date']
# covid['month']=x

covid['year']=covid['date'].str[0:4]
covid['month']=covid['date'].str[5:7]
covid['mo_yr']=covid['month']+"/"+covid['year']
covid
# Out:
#               date      county       state     fips  cases  deaths  year  \
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0  2020
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0  2020
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0  2020
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0  2020
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0  2020
# ...            ...         ...         ...      ...    ...     ...   ...
# 800432  2020-12-05  Sweetwater     Wyoming  56037.0   2098    10.0  2020
# 800433  2020-12-05       Teton     Wyoming  56039.0   1739     2.0  2020
# 800434  2020-12-05       Uinta     Wyoming  56041.0   1187     5.0  2020
# 800435  2020-12-05    Washakie     Wyoming  56043.0    519     8.0  2020
# 800436  2020-12-05      Weston     Wyoming  56045.0    419     2.0  2020
#
#        month    mo_yr
# 0         01  01/2020
# 1         01  01/2020
# ...

# %%
grp = covid.groupby(['county','state','mo_yr'])[['cases','deaths']].agg(sum)
grp = grp.reset_index()
grp
# Out:
#           county           state    mo_yr  cases  deaths
# 0      Abbeville  South Carolina  03/2020     32     0.0
# 1      Abbeville  South Carolina  04/2020    430     0.0
# 2      Abbeville  South Carolina  05/2020   1080     0.0
# 3      Abbeville  South Carolina  06/2020   2187     0.0
# 4      Abbeville  South Carolina  07/2020   5959    65.0
# ...          ...             ...      ...    ...     ...
# 30756    Ziebach    South Dakota  08/2020   1040     0.0
# 30757    Ziebach    South Dakota  09/2020   1734     0.0
# 30758    Ziebach    South Dakota  10/2020   2418    36.0
# 30759    Ziebach    South Dakota  11/2020   4405   115.0
# 30760    Ziebach    South Dakota  12/2020   1121    35.0
#
# [30761 rows x 5 columns]

# %%
X = zori.iloc[:,3:87].fillna(0)
y = zori.iloc[:,88].fillna(0)
zori.isnull().sum()/len(zori)
# Out:
# RegionID      0.000000
# RegionName    0.000000
# SizeRank      0.000000
# 2014-01       0.066038
# 2014-02       0.009434
#                 ...
# 2021-01       0.000000
# 2021-02       0.000000
# 2021-03       0.000000
# 2021-04       0.000000
# 2021-05       0.009434
# Length: 92, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X,y,test_size=.25)

ols = LinearRegression()
ols.fit(X_tr,y_tr)
ols.score(X_tr,y_tr)
ols.score(X_te,y_te)

# np.mean(np.array(y_te - ols.predict(X_te)))
# Out:
# 0.8887393566082412
